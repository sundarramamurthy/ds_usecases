# %% [markdown]
# # Stock Price Trading using Digital Twin Model

# %%
import random
import yfinance as yf

class StockDigitalTwin:
    def __init__(self, initial_price):
        self.current_price = initial_price
        self.history = [initial_price]

    def generate_price(self):
        # Simulate price changes based on a random walk
        price_change = random.uniform(-2, 2)  # Simulating price changes between -2 and 2
        self.current_price += price_change
        self.history.append(self.current_price)

    def fetch_real_time_price(self, ticker, period="1d"):
        try:
            stock_data = yf.Ticker(ticker)
            return stock_data.history(period=period)["Close"].iloc[-1]
        except Exception as e:
            print(f"Error fetching data for {ticker}: {e}")
            return None

    def calculate_moving_average(self, window_size):
        if len(self.history) < window_size:
            return None
        return sum(self.history[-window_size:]) / window_size

def main():
    initial_price = 100  # Set the initial stock price
    window_size = 5  # Moving average window size
    stock_symbols = ["AAPL", "GOOGL", "MSFT"]  # List of stock symbols (you can change this)

    stocks = [StockDigitalTwin(initial_price) for _ in range(len(stock_symbols))]

    for _ in range(30):
        for i, stock in enumerate(stocks):
            stock.generate_price()
            real_time_price = stock.fetch_real_time_price(stock_symbols[i], period="5d")  # Fetch data for the last 5 days
            
            if real_time_price is not None:
                moving_average = stock.calculate_moving_average(window_size)

                print(f"Stock: {stock_symbols[i]} | Current Price: {real_time_price:.2f}", end=" | ")

                if moving_average is not None:
                    print(f"Moving Average ({window_size}): {moving_average:.2f}", end=" | ")
                    if real_time_price > moving_average:
                        print("Buy signal")
                    else:
                        print("Sell signal")
                else:
                    print("Not enough data for moving average calculation")
            else:
                print(f"Skipping analysis for {stock_symbols[i]} due to data availability issue")

        print("=" * 50)

if __name__ == "__main__":
    main()
# Out:
# Stock: AAPL | Current Price: 177.87 | Not enough data for moving average calculation
# Stock: GOOGL | Current Price: 130.42 | Not enough data for moving average calculation
# Stock: MSFT | Current Price: 323.10 | Not enough data for moving average calculation
# ==================================================
# Stock: AAPL | Current Price: 177.86 | Not enough data for moving average calculation
# Stock: GOOGL | Current Price: 130.42 | Not enough data for moving average calculation
# Stock: MSFT | Current Price: 323.11 | Not enough data for moving average calculation
# ==================================================
# Stock: AAPL | Current Price: 177.86 | Not enough data for moving average calculation
# Stock: GOOGL | Current Price: 130.42 | Not enough data for moving average calculation
# Stock: MSFT | Current Price: 323.10 | Not enough data for moving average calculation
# ==================================================
# Stock: AAPL | Current Price: 177.87 | Moving Average (5): 100.81 | Buy signal
# Stock: GOOGL | Current Price: 130.42 | Moving Average (5): 98.47 | Buy signal
# Stock: MSFT | Current Price: 323.10 | Moving Average (5): 100.03 | Buy signal
# ==================================================
# Stock: AAPL | Current Price: 177.86 | Moving Average (5): 100.80 | Buy signal
# Stock: GOOGL | Current Price: 130.42 | Moving Average (5): 97.81 | Buy signal
# Stock: MSFT | Current Price: 323.11 | Moving Average (5): 100.05 | Buy signal
# ==================================================
# Stock: AAPL | Current Price: 177.86 | Moving Average (5): 100.58 | Buy signal
# Stock: GOOGL | Current Price: 130.42 | Moving Average (5): 97.01 | Buy signal
# Stock: MSFT | Current Price: 323.11 | Moving Average (5): 100.53 | Buy signal
# ==================================================
# Stock: AAPL | Current Price: 177.86 | Moving Average (5): 100.83 | Buy signal
# Stock: GOOGL | Current Price: 130.42 | Moving Average (5): 96.22 | Buy signal
# Stock: MSFT | Current Price: 323.11 | Moving Average (5): 101.35 | Buy signal
# ==================================================
# Stock: AAPL | Current Price: 177.86 | Moving Average (5): 101.16 | Buy signal
# Stock: GOOGL | Current Price: 130.42 | Moving Average (5): 94.78 | Buy signal
# Stock: MSFT | Current Price: 323.11 | Moving Average (5): 102.12 | Buy signal
# ==================================================
# Stock: AAPL | Current Price: 177.86 | Moving Average (5): 101.34 | Buy signal
# Stock: GOOGL | Current Price: 130.42 | Moving Average (5): 93.45 | Buy signal
# Stock: MSFT | Current Price: 323.10 | Moving Average (5): 102.65 | Buy signal
# ==================================================
# Stock: AAPL | Current Price: 177.86 | Moving Average (5): 101.41 | Buy signal
# Stock: GOOGL | Current Price: 130.42 | Moving Average (5): 92.00 | Buy signal
# Stock: MSFT | Current Price: 323.11 | Moving Average (5): 103.57 | Buy signal
# ==================================================
# Stock: AAPL | Current Price: 177.87 | Moving Average (5): 101.15 | Buy signal
# Stock: GOOGL | Current Price: 130.42 | Moving Average (5): 90.55 | Buy signal
# Stock: MSFT | Current Price: 323.11 | Moving Average (5): 104.06 | Buy signal
# ==================================================
# Stock: AAPL | Current Price: 177.86 | Moving Average (5): 100.28 | Buy signal
# Stock: GOOGL | Current Price: 130.42 | Moving Average (5): 89.21 | Buy signal
# Stock: MSFT | Current Price: 323.11 | Moving Average (5): 104.17 | Buy signal
# ==================================================
# Stock: AAPL | Current Price: 177.86 | Moving Average (5): 99.73 | Buy signal
# Stock: GOOGL | Current Price: 130.42 | Moving Average (5): 87.81 | Buy signal
# Stock: MSFT | Current Price: 323.11 | Moving Average (5): 103.80 | Buy signal
# ==================================================
# Stock: AAPL | Current Price: 177.87 | Moving Average (5): 99.47 | Buy signal
# Stock: GOOGL | Current Price: 130.42 | Moving Average (5): 86.63 | Buy signal
# Stock: MSFT | Current Price: 323.11 | Moving Average (5): 103.26 | Buy signal
# ==================================================
# Stock: AAPL | Current Price: 177.86 | Moving Average (5): 99.21 | Buy signal
# Stock: GOOGL | Current Price: 130.42 | Moving Average (5): 85.57 | Buy signal
# Stock: MSFT | Current Price: 323.11 | Moving Average (5): 102.92 | Buy signal
# ==================================================
# Stock: AAPL | Current Price: 177.86 | Moving Average (5): 98.97 | Buy signal
# Stock: GOOGL | Current Price: 130.42 | Moving Average (5): 85.19 | Buy signal
# MSFT: No price data found, symbol may be delisted (period=5d)
# Error fetching data for MSFT: single positional indexer is out-of-bounds
# Skipping analysis for MSFT due to data availability issue
# ==================================================
# Stock: AAPL | Current Price: 177.81 | Moving Average (5): 99.28 | Buy signal
# GOOGL: No price data found, symbol may be delisted (period=5d)
# Error fetching data for GOOGL: single positional indexer is out-of-bounds
# Skipping analysis for GOOGL due to data availability issue
# Stock: MSFT | Current Price: 322.82 | Moving Average (5): 102.18 | Buy signal
# ==================================================
# Stock: AAPL | Current Price: 177.76 | Moving Average (5): 99.55 | Buy signal
# Stock: GOOGL | Current Price: 130.22 | Moving Average (5): 85.76 | Buy signal
# Stock: MSFT | Current Price: 322.82 | Moving Average (5): 102.46 | Buy signal
# ==================================================
# Stock: AAPL | Current Price: 177.75 | Moving Average (5): 99.29 | Buy signal
# Stock: GOOGL | Current Price: 130.23 | Moving Average (5): 85.85 | Buy signal
# Stock: MSFT | Current Price: 322.83 | Moving Average (5): 102.84 | Buy signal
# ==================================================
# Stock: AAPL | Current Price: 177.75 | Moving Average (5): 99.28 | Buy signal
# Stock: GOOGL | Current Price: 130.23 | Moving Average (5): 86.39 | Buy signal
# Stock: MSFT | Current Price: 322.85 | Moving Average (5): 103.09 | Buy signal
# ==================================================
# Stock: AAPL | Current Price: 177.76 | Moving Average (5): 99.82 | Buy signal
# Stock: GOOGL | Current Price: 130.12 | Moving Average (5): 86.70 | Buy signal
# Stock: MSFT | Current Price: 322.85 | Moving Average (5): 103.12 | Buy signal
# ==================================================
# Stock: AAPL | Current Price: 177.80 | Moving Average (5): 99.78 | Buy signal
# Stock: GOOGL | Current Price: 130.11 | Moving Average (5): 87.04 | Buy signal
# Stock: MSFT | Current Price: 322.78 | Moving Average (5): 103.53 | Buy signal
# ==================================================
# Stock: AAPL | Current Price: 177.80 | Moving Average (5): 99.61 | Buy signal
# Stock: GOOGL | Current Price: 130.11 | Moving Average (5): 87.20 | Buy signal
# Stock: MSFT | Current Price: 322.85 | Moving Average (5): 103.78 | Buy signal
# ==================================================
# Stock: AAPL | Current Price: 177.80 | Moving Average (5): 100.10 | Buy signal
# Stock: GOOGL | Current Price: 130.11 | Moving Average (5): 87.34 | Buy signal
# Stock: MSFT | Current Price: 322.80 | Moving Average (5): 103.74 | Buy signal
# ==================================================
# Stock: AAPL | Current Price: 177.83 | Moving Average (5): 100.37 | Buy signal
# Stock: GOOGL | Current Price: 130.20 | Moving Average (5): 87.54 | Buy signal
# Stock: MSFT | Current Price: 322.80 | Moving Average (5): 103.17 | Buy signal
# ==================================================
# Stock: AAPL | Current Price: 177.87 | Moving Average (5): 100.51 | Buy signal
# Stock: GOOGL | Current Price: 130.10 | Moving Average (5): 87.75 | Buy signal
# Stock: MSFT | Current Price: 322.80 | Moving Average (5): 103.15 | Buy signal
# ==================================================
# Stock: AAPL | Current Price: 177.81 | Moving Average (5): 101.32 | Buy signal
# Stock: GOOGL | Current Price: 130.10 | Moving Average (5): 87.42 | Buy signal
# Stock: MSFT | Current Price: 322.82 | Moving Average (5): 102.81 | Buy signal
# ==================================================
# Stock: AAPL | Current Price: 177.82 | Moving Average (5): 102.08 | Buy signal
# Stock: GOOGL | Current Price: 130.10 | Moving Average (5): 87.48 | Buy signal
# Stock: MSFT | Current Price: 322.82 | Moving Average (5): 102.54 | Buy signal
# ==================================================
# Stock: AAPL | Current Price: 177.83 | Moving Average (5): 102.43 | Buy signal
# Stock: GOOGL | Current Price: 130.10 | Moving Average (5): 87.76 | Buy signal
# Stock: MSFT | Current Price: 322.85 | Moving Average (5): 103.01 | Buy signal
# ==================================================
# Stock: AAPL | Current Price: 177.82 | Moving Average (5): 103.08 | Buy signal
# Stock: GOOGL | Current Price: 130.10 | Moving Average (5): 88.02 | Buy signal
# Stock: MSFT | Current Price: 322.82 | Moving Average (5): 103.64 | Buy signal
# ==================================================
